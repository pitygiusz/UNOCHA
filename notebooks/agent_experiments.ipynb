# %%
import os
import sys
import asyncio

# Get project root dynamically from notebook path
notebook_path = dbutils.notebook.entry_point.getDbutils().notebook().getContext().notebookPath().get()
# Convert logical path to file system path
project_root = "/Workspace" + os.path.dirname(os.path.dirname(notebook_path))
src_path = os.path.join(project_root, "src")

if src_path not in sys.path:
    sys.path.insert(0, src_path)

from src.quattroformaggi.QueryInterpreter import interpret_query

# %%
os.environ["ANTHROPIC_API_KEY"] = dbutils.secrets.get(scope="datathon-scope", key="ANTHROPIC_API_KEY")

# %%
result = await interpret_query("show underfunded food crises in the Sahel since 2022")
print(result.model_dump_json())
