-- %%
CREATE OR REPLACE TABLE unocha.default.master_table_step_2 AS
select *
from unocha.default.master_table_step_1
union
select
  Country as country_code,
  null as cluster_code,
  population as population,
  null as in_need,
  null as targeted,
  year as year
from unocha.default.population_full
